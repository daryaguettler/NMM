# %% [markdown]
# # NMM 2026 Homework
#
# index of all homework notebooks (links and short descriptions).

# %% [markdown]
# ## HW1
#
# - **[Spheres](notebooks/hw1/Spheres.ipynb)**
# - **[LinAlgCalc](notebooks/hw1/LinAlgCalc.ipynb)**
