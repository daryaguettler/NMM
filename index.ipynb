# %% [markdown]
# # NMM 2026 Homework
#
# index of all homework notebooks

# %% [markdown]
# ## HW1
#
# - **[Mathematical Computing](notebooks/hw1/MathematicalComputing.ipynb)**
# - **[Linear Algebra and Calculus](notebooks/hw1/LinAlgCalc.ipynb)**

# %% [markdown]
# ## HW2
#
# - **[Differential Equations](notebooks/hw2/differentialeqs.ipynb)**
# - **[Drum Head Modes](notebooks/hw2/drumhead.ipynb)**

# %% [markdown]
# ## HW3
#
# - **[Finite Differences](notebooks/hw3/FiniteDiff.ipynb)**

# %% [markdown]
# ## HW4
#
# - **[Finite Elements](notebooks/hw4/FiniteElements.ipynb)**

# %% [markdown]
# ## HW5
# - **[Discrete Elements](notebooks/hw5/DiscreteElements.ipynb)**

# %% [markdown]
# ## HW6
# - **[Random Systems](notebooks/hw6/RandomSystems.ipynb)**

# %% [markdown]
# ## HW7
# - **[Transform](notebooks/hw7/Transforms.ipynb)**

# %% [markdown]
# Project Proposal
# - **[Project Proposal](notebooks/final_project/final_project_ideas.ipynb)**

# %% [markdown]
# ## HW8
# - **[FunctionFitting](notebooks/hw8/FunctionFitting.ipynb)**

# %% [markdown]
# ## HW9
# - **[Search](notebooks/hw9/Search.ipynb)**
